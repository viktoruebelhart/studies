# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoruebelhart/studies/blob/main/estudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(11)
# Out:
# int

# %%
type(11.52)
# Out:
# float

# %%
type("hello 101")
# Out:
# str

# %%
float(2)
# Out:
# 2.0

# %%
int(1.1)
# Out:
# 1

# %%
type(True)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
int(3.99)
# Out:
# 3

# %%
11//2
# Out:
# 5

# %%
x = 4%3
x
# Out:
# 1

# %%
my_string="Coco de gato"
new_text = my_string.replace("de", "Hi")

new_text
# Out:
# 'Coco Hi gato'

# %%
semespaco = new_text.replace(" ", "")
semespaco
# Out:
# 'CocoHigato'

# %%
my_string="Hello"
substring = my_string[0:4]
substring
# Out:
# 'Hell'

# %%
my_string="Hello Amanda"
split_text = my_string.split(",")
split_text
# Out:
# ['Hello Amanda']

# %%
type(split_text)
# Out:
# list

# %%
my_string="   Hello Amanda   "
trimmed = my_string.strip( )
trimmed
# Out:
# 'Hello Amanda'

# %%
A=(1,2,3,4,5)
A[1:4]
# Out:
# (2, 3, 4)

# %%
A = [1]
A.append([2, 3, 4, 5])
len(A)
# Out:
# 2

# %%
x = {"a":1,"b":2}
x.keys()
# Out:
# dict_keys(['a', 'b'])
